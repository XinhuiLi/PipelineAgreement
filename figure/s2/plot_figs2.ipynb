# %%
import os
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
type='power'
hbn_afni_good=np.load('/Users/xinhui.li/Documents/reproducibility/PipelineHarmonization/figure/s2/HBN_AFNI_FD_'+type+'_good.npy')
hbn_afni_bad=np.load('/Users/xinhui.li/Documents/reproducibility/PipelineHarmonization/figure/s2/HBN_AFNI_FD_'+type+'_bad.npy')
hbn_fsl_good=np.load('/Users/xinhui.li/Documents/reproducibility/PipelineHarmonization/figure/s2/HBN_FSL_FD_'+type+'_good.npy')
hbn_fsl_bad=np.load('/Users/xinhui.li/Documents/reproducibility/PipelineHarmonization/figure/s2/HBN_FSL_FD_'+type+'_bad.npy')

# %%
hbn_afni_good_fd_list, hbn_afni_bad_fd_list = [], []
hbn_fsl_good_fd_list, hbn_fsl_bad_fd_list = [], []

for i in range(6):
    hbn_afni_good_fd_list.append(hbn_afni_good[i,:])
    hbn_afni_bad_fd_list.append(hbn_afni_bad[i,:])
    hbn_fsl_good_fd_list.append(hbn_fsl_good[i,:])
    hbn_fsl_bad_fd_list.append(hbn_fsl_bad[i,:])

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

title_string = 'FD Power Correlation'

sns.boxplot(data=hbn_afni_good_fd_list, ax=axs[0,0])
axs[0,0].set_ylim([0.58,1.02])
axs[0,0].set_xticklabels(['mean vs median', 'mean vs first', 'mean vs last', 'median vs first', 'median vs last', 'first vs last'], rotation=15)
axs[0,0].set_ylabel(title_string)
axs[0,0].set_title('AFNI 3dvolreg low motion', fontsize=15, fontweight='bold')

sns.boxplot(data=hbn_afni_bad_fd_list, ax=axs[0,1])
axs[0,1].set_ylim([0.58,1.02])
axs[0,1].set_xticklabels(['mean vs median', 'mean vs first', 'mean vs last', 'median vs first', 'median vs last', 'first vs last'], rotation=15)
axs[0,1].set_ylabel(title_string)
axs[0,1].set_title('AFNI 3dvolreg high motion', fontsize=15, fontweight='bold')

sns.boxplot(data=hbn_fsl_good_fd_list, ax=axs[1,0])
axs[1,0].set_ylim([0.58,1.02])
axs[1,0].set_xticklabels(['mean vs median', 'mean vs first', 'mean vs last', 'median vs first', 'median vs last', 'first vs last'], rotation=15)
axs[1,0].set_ylabel(title_string)
axs[1,0].set_title('FSL MCFLIRT low motion', fontsize=15, fontweight='bold')

sns.boxplot(data=hbn_fsl_bad_fd_list, ax=axs[1,1])
axs[1,1].set_ylim([0.58,1.02])
axs[1,1].set_xticklabels(['mean vs median', 'mean vs first', 'mean vs last', 'median vs first', 'median vs last', 'first vs last'], rotation=15)
axs[1,1].set_ylabel(title_string)
axs[1,1].set_title('FSL MCFLIRT high motion', fontsize=15, fontweight='bold')

plt.tight_layout()
plt.savefig('FigureS2.1.png', dpi=300)

# %%
type='jenkinson'
hbn_afni_good=np.load('/Users/xinhui.li/Documents/reproducibility/PipelineHarmonization/figure/s2/HBN_AFNI_FD_'+type+'_good.npy')
hbn_afni_bad=np.load('/Users/xinhui.li/Documents/reproducibility/PipelineHarmonization/figure/s2/HBN_AFNI_FD_'+type+'_bad.npy')
hbn_fsl_good=np.load('/Users/xinhui.li/Documents/reproducibility/PipelineHarmonization/figure/s2/HBN_FSL_FD_'+type+'_good.npy')
hbn_fsl_bad=np.load('/Users/xinhui.li/Documents/reproducibility/PipelineHarmonization/figure/s2/HBN_FSL_FD_'+type+'_bad.npy')

# %%
hbn_afni_good_fd_list, hbn_afni_bad_fd_list = [], []
hbn_fsl_good_fd_list, hbn_fsl_bad_fd_list = [], []

for i in range(6):
    hbn_afni_good_fd_list.append(hbn_afni_good[i,:])
    hbn_afni_bad_fd_list.append(hbn_afni_bad[i,:])
    hbn_fsl_good_fd_list.append(hbn_fsl_good[i,:])
    hbn_fsl_bad_fd_list.append(hbn_fsl_bad[i,:])

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 8))

title_string = 'FD Jenkinson Correlation'

sns.boxplot(data=hbn_afni_good_fd_list, ax=axs[0,0])
axs[0,0].set_ylim([0.58,1.02])
axs[0,0].set_xticklabels(['mean vs median', 'mean vs first', 'mean vs last', 'median vs first', 'median vs last', 'first vs last'], rotation=15)
axs[0,0].set_ylabel(title_string)
axs[0,0].set_title('AFNI 3dvolreg low motion', fontsize=15, fontweight='bold')

sns.boxplot(data=hbn_afni_bad_fd_list, ax=axs[0,1])
axs[0,1].set_ylim([0.58,1.02])
axs[0,1].set_xticklabels(['mean vs median', 'mean vs first', 'mean vs last', 'median vs first', 'median vs last', 'first vs last'], rotation=15)
axs[0,1].set_ylabel(title_string)
axs[0,1].set_title('AFNI 3dvolreg high motion', fontsize=15, fontweight='bold')

sns.boxplot(data=hbn_fsl_good_fd_list, ax=axs[1,0])
axs[1,0].set_ylim([0.58,1.02])
axs[1,0].set_xticklabels(['mean vs median', 'mean vs first', 'mean vs last', 'median vs first', 'median vs last', 'first vs last'], rotation=15)
axs[1,0].set_ylabel(title_string)
axs[1,0].set_title('FSL MCFLIRT low motion', fontsize=15, fontweight='bold')

sns.boxplot(data=hbn_fsl_bad_fd_list, ax=axs[1,1])
axs[1,1].set_ylim([0.58,1.02])
axs[1,1].set_xticklabels(['mean vs median', 'mean vs first', 'mean vs last', 'median vs first', 'median vs last', 'first vs last'], rotation=15)
axs[1,1].set_ylabel(title_string)
axs[1,1].set_title('FSL MCFLIRT high motion', fontsize=15, fontweight='bold')

plt.tight_layout()
plt.savefig('FigureS2.2.png', dpi=300)

# %%
fig, axs = plt.subplots(4, 4, figsize=(15, 12))

for i in range(1,4):
    for j in range(4-i,4):
        axs[i, j].axis('off')

path = '/Users/xinhui.li/Documents/reproducibility/LA/Reproducibility_Analysis/ROI/ROI_Schaefer200'
reference = ['mean', 'median', 'first', 'last']

for i, r1 in enumerate(reference):
    for j, r2 in enumerate(reference[i:]):
        p1 = os.path.join(path, 'motion_afni_'+r1)
        p2 = os.path.join(path, 'motion_fsl_'+r2)
        print(p1, p2)
        p1_list = os.listdir(p1)

        corr = np.zeros( len(p1_list) )
        for k, sub in enumerate(p1_list):
            roi1 = np.loadtxt( os.path.join(path, 'motion_afni_'+r1, p1_list[k]) )
            roi2 = np.loadtxt( os.path.join(path, 'motion_afni_'+r2, p2_list[k]) )
            c, _ = pearsonr(roi1, roi2)
            corr[k] = c
        print(i, j)
        a = sns.swarmplot(x=corr.T, ax=axs[i,j], size=8, orient='v')
        a.set(xticklabels=[])
        a.set(xlabel=None)
        a.set(ylabel=None)
        # a.set(title='AFNI '+r1+' vs FSL '+r2)
        a.set(ylim=(0.949, 1.01))

fig.tight_layout()
plt.savefig('/Users/xinhui.li/Documents/reproducibility/PipelineHarmonization/figure/s2/FigureS2.3.png',bbox_inches='tight',dpi=200)
# Out:
# /Users/xinhui.li/Documents/reproducibility/LA/Reproducibility_Analysis/ROI/ROI_Schaefer200/motion_afni_mean /Users/xinhui.li/Documents/reproducibility/LA/Reproducibility_Analysis/ROI/ROI_Schaefer200/motion_fsl_mean
# 0 0
# /Users/xinhui.li/Documents/reproducibility/LA/Reproducibility_Analysis/ROI/ROI_Schaefer200/motion_afni_mean /Users/xinhui.li/Documents/reproducibility/LA/Reproducibility_Analysis/ROI/ROI_Schaefer200/motion_fsl_median
# 0 1
# /Users/xinhui.li/Documents/reproducibility/LA/Reproducibility_Analysis/ROI/ROI_Schaefer200/motion_afni_mean /Users/xinhui.li/Documents/reproducibility/LA/Reproducibility_Analysis/ROI/ROI_Schaefer200/motion_fsl_first
# 0 2
# /Users/xinhui.li/Documents/reproducibility/LA/Reproducibility_Analysis/ROI/ROI_Schaefer200/motion_afni_mean /Users/xinhui.li/Documents/reproducibility/LA/Reproducibility_Analysis/ROI/ROI_Schaefer200/motion_fsl_last
# 0 3
# ...
